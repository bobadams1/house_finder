# %% [markdown]
# # Sourcing Satelite Imagery from Google's Earth Engine

# %%
#Imports
import numpy as np
import pandas as pd
import os
import geopandas as gpd
import shapely
import ee
from ee.data import exportMap
import folium
import io

# !pip install geemap
import geemap

# !brew install --cask wkhtmltopdf
# !pip install imgkit
import imgkit

from keys import thunderforest

# %%
#Authenticate Earth Engine
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=YB-feKSlaB_j6jjwjXEQJJSuYJFlr_1yC7s2S6rCn58&tc=veAcODvdBWC2ynxxSTNZ3tq6LyfDvAghtLb1zEYUJyI&cc=dZ0cuow6PsBO7Dmx-E4-JeSnHiwglmD23oStGFLjsBs>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=YB-feKSlaB_j6jjwjXEQJJSuYJFlr_1yC7s2S6rCn58&tc=veAcODvdBWC2ynxxSTNZ3tq6LyfDvAghtLb1zEYUJyI&cc=dZ0cuow6PsBO7Dmx-E4-JeSnHiwglmD23oStGFLjsBs</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AZEOvhU3jlkFeUSRuM9YF3NgEQR8XUvniqGHngF_36dXnZ4gu7_LmUsB9eE
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
#Test API Connection
dem = ee.Image('USGS/SRTMGL1_003')
xy = ee.Geometry.Point([86.9250, 27.9881])
elev = dem.sample(xy, 30).first().get('elevation').getInfo()
print('Mount Everest elevation (m):', elev)
# Out:
# Mount Everest elevation (m): 8729

# %% [markdown]
# Cite: [Google's Earth Engine Colab Setup Guide](https://colab.research.google.com/github/google/earthengine-api/blob/master/python/examples/ipynb/ee-api-colab-setup.ipynb)

# %% [markdown]
# ## Select Projection and Imagery from Open Source Google Earth Engine

# %%
# Define a method for displaying Earth Engine image tiles to folium map.
def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
    tiles = map_id_dict['tile_fetcher'].url_format,
    attr = 'Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    name = name,
    overlay = False,
    control = True
  ).add_to(self)

# Add EE drawing method to folium.
folium.Map.add_ee_layer = add_ee_layer

# Set visualization parameters.
dem_vis_params = {
  'min': 0,
  'max': 1500,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

# Create a folium map object.
my_map = folium.Map(location=[39.6, 19.83], width = 1000, height = 1000, zoom_start=10.5)

# Add the elevation model to the map object.
my_map.add_ee_layer(dem.updateMask(dem.gt(0)), dem_vis_params, 'DEM')
# my_map.add_ee_layer()

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba6242cd2110ed9ae50d742336eaeb0a {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba6242cd2110ed9ae50d742336eaeb0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba6242cd2110ed9ae50d742336eaeb0a = L.map(
#                 &quot;map_ba6242cd2110ed9ae50d742336eaeb0a&quot;,
#                 {
#                     center: [39.6, 19.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a9dea9bd82ad6a29c2e849aa45a280 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba6242cd2110ed9ae50d742336eaeb0a);
#
#
#             var tile_layer_7af8948f6a2ac69ff1ead1e0542a04ee = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/59177d8597ffd392c9ac527baf6b1515-875e02d53bd7d7a382b7a028da250220/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba6242cd2110ed9ae50d742336eaeb0a);
#
#
#             var layer_control_4cc33ef1b2b63b96fe42e64794140a82 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b1a9dea9bd82ad6a29c2e849aa45a280,
#                     &quot;DEM&quot; : tile_layer_7af8948f6a2ac69ff1ead1e0542a04ee,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_4cc33ef1b2b63b96fe42e64794140a82.base_layers,
#                 layer_control_4cc33ef1b2b63b96fe42e64794140a82.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_ba6242cd2110ed9ae50d742336eaeb0a);
#             tile_layer_7af8948f6a2ac69ff1ead1e0542a04ee.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Sourcing and Testing: Map Layers from [leaflet providers on Github](http://leaflet-extras.github.io/leaflet-providers/preview/)

# %%
#Thunderforest_MobileAtlas
folium.TileLayer()
my_map = folium.Map(location=[39.59, 19.83],
                    width = 800, height = 800,
                    zoom_start=10.5,
                    tiles = 'https://tile.thunderforest.com/mobile-atlas/{z}/{x}/{y}.png?'+'apikey='+thunderforest,
                    attr='<a href="http://www.thunderforest.com/">Thunderforest</a>, &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
                    min_zoom=10,
                    name='Thunderforest_MobileAtlas',overlay=True)

# var Thunderforest_MobileAtlas = L.tileLayer('https://{s}.tile.thunderforest.com/mobile-atlas/{z}/{x}/{y}.png?apikey={apikey}', {
	# attribution: '&copy; <a href="http://www.thunderforest.com/">Thunderforest</a>, &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
	# apikey: '<your apikey>',
	# maxZoom: 22
# });
# Display the map.
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c18899c77156d59712dba8255f633504 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 800.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c18899c77156d59712dba8255f633504&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c18899c77156d59712dba8255f633504 = L.map(
#                 &quot;map_c18899c77156d59712dba8255f633504&quot;,
#                 {
#                     center: [39.59, 19.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Thunderforest_MobileAtlas&quot;,
#                     overlay: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21051e922294290cd9cd4df9bef5fecb = L.tileLayer(
#                 &quot;https://tile.thunderforest.com/mobile-atlas/{z}/{x}/{y}.png?apikey=11823168288a4286a7decf6f7076b3ea&quot;,
#                 {&quot;attribution&quot;: &quot;\u003ca href=\&quot;http://www.thunderforest.com/\&quot;\u003eThunderforest\u003c/a\u003e, \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c18899c77156d59712dba8255f633504);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Google Maps Satelite Imagery
# cite: https://github.com/gee-community/geemap/blob/master/geemap/basemaps.py
folium.TileLayer()
my_map = folium.Map(location=[39.6, 19.83],
                    width = 800, height = 800,
                    zoom_start=10.3,
                    tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                    attr='Google',
                    name='Google Satelite')

# Display the map.
display(my_map)
my_map.save('../images/Corfu_Google_Satelite.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a27fdc6897e36642cc16d615c4fe20c2 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 800.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a27fdc6897e36642cc16d615c4fe20c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a27fdc6897e36642cc16d615c4fe20c2 = L.map(
#                 &quot;map_a27fdc6897e36642cc16d615c4fe20c2&quot;,
#                 {
#                     center: [39.6, 19.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Google Satelite&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f9fb28053b95c3bbee9b45c46005142 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a27fdc6897e36642cc16d615c4fe20c2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Leverage ARCGIS Imagery at a high zoom level to to iterate over a map and capture photos

# %%
# ESRI World
my_map = folium.Map(location=[39.494, 19.873],
                    width = 500, height = 500,
                    zoom_start=18,
                    tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    attr='Tiles - Esri - Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',
                    min_zoom=10,
                    name='ESRI-World')

# Display the map.
display(my_map)
my_map.save('../images/Agios_Mattheos_ESRI_World.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4f261428d5e14002555c9372fda74bc {
#                     position: relative;
#                     width: 500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4f261428d5e14002555c9372fda74bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4f261428d5e14002555c9372fda74bc = L.map(
#                 &quot;map_d4f261428d5e14002555c9372fda74bc&quot;,
#                 {
#                     center: [39.494, 19.873],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;ESRI-World&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df539952f8772615469cd93919398f97 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles - Esri - Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4f261428d5e14002555c9372fda74bc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Google Maps Satelite Imagery
# cite: https://github.com/gee-community/geemap/blob/master/geemap/basemaps.py
folium.TileLayer()
my_map = folium.Map(location=[39.494, 19.873],
                    width = 500, height = 500,
                    zoom_start=18,
                    tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                    attr='Google',
                    name='Google Satelite')

# Display the map.
display(my_map)
my_map.save('../images/Agios_Mattheos_Google_Satelite.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba82ac550ea596019ee498f762d7cd40 {
#                     position: relative;
#                     width: 500.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba82ac550ea596019ee498f762d7cd40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba82ac550ea596019ee498f762d7cd40 = L.map(
#                 &quot;map_ba82ac550ea596019ee498f762d7cd40&quot;,
#                 {
#                     center: [39.494, 19.873],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Google Satelite&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f567c34afbab7d9380909d55066882d0 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba82ac550ea596019ee498f762d7cd40);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
# ## Capture Small Scale Images

# %% [markdown]
# ***Image Capture Process:***
#
# 1. Define Island Boundary via geojson or geographic polygon (see [02_Shoreline Boundary](code/02_Shoreline_Boundary.ipynb))
# 2. Initiate a grid to search over the island
# 3. If the starting geolocation is outside the geojson boundary, skip (this prevents hundreds of all blue images)
# 4. Capture image with name as lon_lat.png

# %%
# Read in Coastline Data
# Cite: https://geopandas.org/en/stable/docs/user_guide/io.html
coastline_shp = gpd.read_file('../data/clean_data/coastlines/corfu.shp')

# %%
type(coastline_shp)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
coastline_shp.shape
# Out:
# (1, 2)

# %%
first_geom = coastline_shp.iloc[0]
coastline = gpd.GeoSeries(first_geom.geometry)

# %%
coastline
# Out:
# 0    POLYGON ((19.68731 39.79651, 19.68751 39.79655...
# dtype: geometry

# %%
# Cite: https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoSeries.total_bounds.html
min_lon, min_lat, max_lon, max_lat = coastline.total_bounds

# %%
print(f"Westernmost Longitude: {min_lon}")
print(f"Easternmost Longitude: {max_lon}")
print(f"Southernmost Latitude: {min_lat}")
print(f"Northernmost Latitude: {max_lat}")
# Out:
# Westernmost Longitude: 19.629380550436906
# Easternmost Longitude: 20.12227358704468
# Southernmost Latitude: 39.36066892455921
# Northernmost Latitude: 39.822028253950144

# %%
#Estimate the number of images needed to cover the island at the set offsets
print(f"Vertical: {(max_lat - min_lat) / 0.0012}")
print(f"Horizontal: {(max_lon - min_lon) / 0.0016}")

print(f"{round(((max_lat - min_lat) / 0.0012) * (max_lon - min_lon) / 0.0016)} Images Per Grid")
# Out:
# Vertical: 384.46610782578125
# Horizontal: 308.0581478798594
# 118438 Images Per Grid

# %% [markdown]
# ## Capture Images Gridwise within the boundaries of the island

# %%
lat = 39.596
lon = 19.8015
m = folium.Map(location=[lat, lon],
                    width = 300, height = 310,
                    min_zoom=18, max_zoom = 18,
                    tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                    attr='Google',
                    name='Google Satelite',
                    disable_3d=True,
                    control_scale=False,
                   zoom_control = False,
                   scrollWheelZoom = False,
                   dragging = False)

# Display the map.
display(m)

#Save the Image - Folium Default is html
#cite: https://python-visualization.github.io/folium/plugins.html?highlight=save
# m.save('image.html')

# imgkit approach
#cite: Mohit Chandel https://stackoverflow.com/a/60598918

## Save as html file to temp folder
m.save(f'../images/temp/{lon}_{lat}_sat.html')

## Convert to png file and save to permanent folder
imgkit.from_file(f'../images/temp/{lon}_{lat}_sat.html',f'../images/satelite_tiles/{lon}_{lat}_sat.png')

##Destroy html file 
os.remove(f'../images/temp/{lon}_{lat}_sat.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = true;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac7340d1d657f2d7abfd431b53cacf6b {
#                     position: relative;
#                     width: 300.0px;
#                     height: 310.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac7340d1d657f2d7abfd431b53cacf6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac7340d1d657f2d7abfd431b53cacf6b = L.map(
#                 &quot;map_ac7340d1d657f2d7abfd431b53cacf6b&quot;,
#                 {
#                     center: [39.596, 19.8015],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: false,
#                     preferCanvas: false,
#                     name: &quot;Google Satelite&quot;,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_131fb68e84d91a4fed73e39527e770d8 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 18, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac7340d1d657f2d7abfd431b53cacf6b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Loading page (1/2)
# Rendering (2/2)
# Done

# %%
# Function Approach: Plot Map, Check for Boundaries, Save .png file over a set grid.

# %%
def create_map_tiles(long, lati, border, width, height):
    point = shapely.Point(lati, long)
    #Continue if the selected point does not lie within the border geometry
    if shapely.contains(border, point).item():
        #Generate the map with Folium
        m = folium.Map(location=[long, lati],
                    width = width, height = height,
                    min_zoom=18, max_zoom = 18,
                    tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                    attr='Google',
                    name='Google Satelite',
                    disable_3d=True,
                    control_scale=False,
                    zoom_control = False,
                    scrollWheelZoom = False,
                    dragging = False)
        # display(m)
        
        # Save the map as an html from folium
        m.save(f'../images/temp/{long}_{lati}_sat.html')
        ## Convert to png file and save to permanent folder
        imgkit.from_file(f'../images/temp/{long}_{lati}_sat.html',f'../images/satelite_tiles/{long}_{lati}_sat.png')
        ##Destroy html file 
        os.remove(f'../images/temp/{long}_{lati}_sat.html') #regex to read in lonlat from filepath
        return
    else:
        return

# %%
#Single Tile Test
create_map_tiles(39.596, 19.83, coastline, 300 , 300)
# Out:
# POINT (19.83 39.596)
# Loading page (1/2)
# Rendering (2/2)
# Done

# %%
#Leverage the movable maps to select the change in latitude and longitude you want to move between capturing images.
border = coastline
lon_interval = 0.0016
width = 300
lat_interval = 0.0012
height = 300


#plot a boundary using the northernmost, easternmost, etc. points in your border geometry
min_lon, min_lat, max_lon, max_lat = coastline.total_bounds

for x in np.arange(min_lat, max_lat, lat_interval):
    for y in np.arange(min_lon, max_lon, lon_interval):
        create_map_tiles(x, y, border, width, height)
# Out:
# POINT (19.629380550436906 39.36066892455921)
# POINT (19.630980550436906 39.36066892455921)
# POINT (19.632580550436906 39.36066892455921)
# POINT (19.634180550436906 39.36066892455921)
# POINT (19.635780550436905 39.36066892455921)
# POINT (19.637380550436905 39.36066892455921)
# POINT (19.638980550436905 39.36066892455921)
# POINT (19.640580550436905 39.36066892455921)
# POINT (19.642180550436905 39.36066892455921)
# POINT (19.643780550436905 39.36066892455921)
# POINT (19.645380550436904 39.36066892455921)
# POINT (19.646980550436904 39.36066892455921)
# POINT (19.648580550436904 39.36066892455921)
# POINT (19.650180550436904 39.36066892455921)
# POINT (19.651780550436904 39.36066892455921)
# POINT (19.653380550436903 39.36066892455921)
# POINT (19.654980550436903 39.36066892455921)
# POINT (19.656580550436903 39.36066892455921)
# POINT (19.658180550436903 39.36066892455921)
# POINT (19.659780550436903 39.36066892455921)
# POINT (19.661380550436903 39.36066892455921)
# POINT (19.662980550436902 39.36066892455921)
# POINT (19.664580550436902 39.36066892455921)
# POINT (19.666180550436902 39.36066892455921)
# POINT (19.667780550436902 39.36066892455921)
# POINT (19.6693805504369 39.36066892455921)
# POINT (19.6709805504369 39.36066892455921)
# POINT (19.6725805504369 39.36066892455921)
# POINT (19.6741805504369 39.36066892455921)
# POINT (19.6757805504369 39.36066892455921)
# POINT (19.6773805504369 39.36066892455921)
# POINT (19.6789805504369 39.36066892455921)
# POINT (19.6805805504369 39.36066892455921)
# POINT (19.6821805504369 39.36066892455921)
# POINT (19.6837805504369 39.36066892455921)
# POINT (19.6853805504369 39.36066892455921)
# POINT (19.6869805504369 39.36066892455921)
# POINT (19.6885805504369 39.36066892455921)
# POINT (19.6901805504369 39.36066892455921)
# POINT (19.6917805504369 39.36066892455921)
# POINT (19.6933805504369 39.36066892455921)
# POINT (19.6949805504369 39.36066892455921)
# POINT (19.6965805504369 39.36066892455921)
# POINT (19.6981805504369 39.36066892455921)
# POINT (19.6997805504369 39.36066892455921)
# POINT (19.701380550436898 39.36066892455921)
# POINT (19.702980550436898 39.36066892455921)
# POINT (19.704580550436898 39.36066892455921)
# POINT (19.706180550436898 39.36066892455921)
# POINT (19.707780550436897 39.36066892455921)
# POINT (19.709380550436897 39.36066892455921)
# POINT (19.710980550436897 39.36066892455921)
# POINT (19.712580550436897 39.36066892455921)
# POINT (19.714180550436897 39.36066892455921)
# POINT (19.715780550436897 39.36066892455921)
# POINT (19.717380550436896 39.36066892455921)
# POINT (19.718980550436896 39.36066892455921)
# POINT (19.720580550436896 39.36066892455921)
# POINT (19.722180550436896 39.36066892455921)
# POINT (19.723780550436896 39.36066892455921)
# POINT (19.725380550436896 39.36066892455921)
# POINT (19.726980550436895 39.36066892455921)
# POINT (19.728580550436895 39.36066892455921)
# POINT (19.730180550436895 39.36066892455921)
# POINT (19.731780550436895 39.36066892455921)
# POINT (19.733380550436895 39.36066892455921)
# POINT (19.734980550436894 39.36066892455921)
# POINT (19.736580550436894 39.36066892455921)
# POINT (19.738180550436894 39.36066892455921)
# POINT (19.739780550436894 39.36066892455921)
# POINT (19.741380550436894 39.36066892455921)
# POINT (19.742980550436894 39.36066892455921)
# POINT (19.744580550436893 39.36066892455921)
# POINT (19.746180550436893 39.36066892455921)
# POINT (19.747780550436893 39.36066892455921)
# POINT (19.749380550436893 39.36066892455921)
# POINT (19.750980550436893 39.36066892455921)
# POINT (19.752580550436893 39.36066892455921)
# POINT (19.754180550436892 39.36066892455921)
# POINT (19.755780550436892 39.36066892455921)
# POINT (19.757380550436892 39.36066892455921)
# POINT (19.758980550436892 39.36066892455921)
# POINT (19.76058055043689 39.36066892455921)
# POINT (19.76218055043689 39.36066892455921)
# POINT (19.76378055043689 39.36066892455921)
# POINT (19.76538055043689 39.36066892455921)
# POINT (19.76698055043689 39.36066892455921)
# POINT (19.76858055043689 39.36066892455921)
# POINT (19.77018055043689 39.36066892455921)
# POINT (19.77178055043689 39.36066892455921)
# POINT (19.77338055043689 39.36066892455921)
# POINT (19.77498055043689 39.36066892455921)
# POINT (19.77658055043689 39.36066892455921)
# POINT (19.77818055043689 39.36066892455921)
# POINT (19.77978055043689 39.36066892455921)
# POINT (19.78138055043689 39.36066892455921)
# POINT (19.78298055043689 39.36066892455921)
# POINT (19.78458055043689 39.36066892455921)
# POINT (19.78618055043689 39.36066892455921)
# POINT (19.78778055043689 39.36066892455921)
# POINT (19.78938055043689 39.36066892455921)
# POINT (19.79098055043689 39.36066892455921)
# POINT (19.792580550436888 39.36066892455921)
# POINT (19.794180550436888 39.36066892455921)
# POINT (19.795780550436888 39.36066892455921)
# POINT (19.797380550436888 39.36066892455921)
# POINT (19.798980550436887 39.36066892455921)
# POINT (19.800580550436887 39.36066892455921)
# POINT (19.802180550436887 39.36066892455921)
# POINT (19.803780550436887 39.36066892455921)
# POINT (19.805380550436887 39.36066892455921)
# POINT (19.806980550436887 39.36066892455921)
# POINT (19.808580550436886 39.36066892455921)
# POINT (19.810180550436886 39.36066892455921)
# POINT (19.811780550436886 39.36066892455921)
# POINT (19.813380550436886 39.36066892455921)
# POINT (19.814980550436886 39.36066892455921)
# POINT (19.816580550436885 39.36066892455921)
# POINT (19.818180550436885 39.36066892455921)
# POINT (19.819780550436885 39.36066892455921)
# POINT (19.821380550436885 39.36066892455921)
# POINT (19.822980550436885 39.36066892455921)
# POINT (19.824580550436885 39.36066892455921)
# POINT (19.826180550436884 39.36066892455921)
# POINT (19.827780550436884 39.36066892455921)
# POINT (19.829380550436884 39.36066892455921)
# POINT (19.830980550436884 39.36066892455921)
# POINT (19.832580550436884 39.36066892455921)
# POINT (19.834180550436884 39.36066892455921)
# POINT (19.835780550436883 39.36066892455921)
# POINT (19.837380550436883 39.36066892455921)
# POINT (19.838980550436883 39.36066892455921)
# POINT (19.840580550436883 39.36066892455921)
# POINT (19.842180550436883 39.36066892455921)
# POINT (19.843780550436882 39.36066892455921)
# POINT (19.845380550436882 39.36066892455921)
# POINT (19.846980550436882 39.36066892455921)
# POINT (19.848580550436882 39.36066892455921)
# POINT (19.850180550436882 39.36066892455921)
# POINT (19.85178055043688 39.36066892455921)
# POINT (19.85338055043688 39.36066892455921)
# POINT (19.85498055043688 39.36066892455921)
# POINT (19.85658055043688 39.36066892455921)
# POINT (19.85818055043688 39.36066892455921)
# POINT (19.85978055043688 39.36066892455921)
# POINT (19.86138055043688 39.36066892455921)
# POINT (19.86298055043688 39.36066892455921)
# POINT (19.86458055043688 39.36066892455921)
# POINT (19.86618055043688 39.36066892455921)
# POINT (19.86778055043688 39.36066892455921)
# POINT (19.86938055043688 39.36066892455921)
# POINT (19.87098055043688 39.36066892455921)
# POINT (19.87258055043688 39.36066892455921)
# POINT (19.87418055043688 39.36066892455921)
# POINT (19.87578055043688 39.36066892455921)
# POINT (19.87738055043688 39.36066892455921)
# POINT (19.87898055043688 39.36066892455921)
# POINT (19.88058055043688 39.36066892455921)
# POINT (19.88218055043688 39.36066892455921)
# POINT (19.883780550436878 39.36066892455921)
# POINT (19.885380550436878 39.36066892455921)
# POINT (19.886980550436878 39.36066892455921)
# POINT (19.888580550436878 39.36066892455921)
# POINT (19.890180550436877 39.36066892455921)
# POINT (19.891780550436877 39.36066892455921)
# POINT (19.893380550436877 39.36066892455921)
# POINT (19.894980550436877 39.36066892455921)
# POINT (19.896580550436877 39.36066892455921)
# POINT (19.898180550436877 39.36066892455921)
# POINT (19.899780550436876 39.36066892455921)
# POINT (19.901380550436876 39.36066892455921)
# POINT (19.902980550436876 39.36066892455921)
# POINT (19.904580550436876 39.36066892455921)
# POINT (19.906180550436876 39.36066892455921)
# POINT (19.907780550436875 39.36066892455921)
# POINT (19.909380550436875 39.36066892455921)
# POINT (19.910980550436875 39.36066892455921)
# POINT (19.912580550436875 39.36066892455921)
# POINT (19.914180550436875 39.36066892455921)
# POINT (19.915780550436875 39.36066892455921)
# POINT (19.917380550436874 39.36066892455921)
# POINT (19.918980550436874 39.36066892455921)
# POINT (19.920580550436874 39.36066892455921)
# POINT (19.922180550436874 39.36066892455921)
# POINT (19.923780550436874 39.36066892455921)
# POINT (19.925380550436874 39.36066892455921)
# POINT (19.926980550436873 39.36066892455921)
# POINT (19.928580550436873 39.36066892455921)
# POINT (19.930180550436873 39.36066892455921)
# POINT (19.931780550436873 39.36066892455921)
# POINT (19.933380550436873 39.36066892455921)
# POINT (19.934980550436872 39.36066892455921)
# POINT (19.936580550436872 39.36066892455921)
# POINT (19.938180550436872 39.36066892455921)
# POINT (19.939780550436872 39.36066892455921)
# POINT (19.94138055043687 39.36066892455921)
# POINT (19.94298055043687 39.36066892455921)
# POINT (19.94458055043687 39.36066892455921)
# POINT (19.94618055043687 39.36066892455921)
# POINT (19.94778055043687 39.36066892455921)
# POINT (19.94938055043687 39.36066892455921)
# POINT (19.95098055043687 39.36066892455921)
# POINT (19.95258055043687 39.36066892455921)
# POINT (19.95418055043687 39.36066892455921)
# POINT (19.95578055043687 39.36066892455921)
# POINT (19.95738055043687 39.36066892455921)
# POINT (19.95898055043687 39.36066892455921)
# POINT (19.96058055043687 39.36066892455921)
# POINT (19.96218055043687 39.36066892455921)
# POINT (19.96378055043687 39.36066892455921)
# POINT (19.96538055043687 39.36066892455921)
# POINT (19.96698055043687 39.36066892455921)
# POINT (19.96858055043687 39.36066892455921)
# POINT (19.97018055043687 39.36066892455921)
# POINT (19.97178055043687 39.36066892455921)
# POINT (19.973380550436868 39.36066892455921)
# POINT (19.974980550436868 39.36066892455921)
# POINT (19.976580550436868 39.36066892455921)
# POINT (19.978180550436868 39.36066892455921)
# POINT (19.979780550436868 39.36066892455921)
# POINT (19.981380550436867 39.36066892455921)
# POINT (19.982980550436867 39.36066892455921)
# POINT (19.984580550436867 39.36066892455921)
# POINT (19.986180550436867 39.36066892455921)
# POINT (19.987780550436867 39.36066892455921)
# POINT (19.989380550436866 39.36066892455921)
# POINT (19.990980550436866 39.36066892455921)
# POINT (19.992580550436866 39.36066892455921)
# POINT (19.994180550436866 39.36066892455921)
# POINT (19.995780550436866 39.36066892455921)
# POINT (19.997380550436866 39.36066892455921)
# POINT (19.998980550436865 39.36066892455921)
# POINT (20.000580550436865 39.36066892455921)
# POINT (20.002180550436865 39.36066892455921)
# POINT (20.003780550436865 39.36066892455921)
# POINT (20.005380550436865 39.36066892455921)
# POINT (20.006980550436865 39.36066892455921)
# POINT (20.008580550436864 39.36066892455921)
# POINT (20.010180550436864 39.36066892455921)
# POINT (20.011780550436864 39.36066892455921)
# POINT (20.013380550436864 39.36066892455921)
# POINT (20.014980550436864 39.36066892455921)
# POINT (20.016580550436863 39.36066892455921)
# POINT (20.018180550436863 39.36066892455921)
# POINT (20.019780550436863 39.36066892455921)
# POINT (20.021380550436863 39.36066892455921)
# POINT (20.022980550436863 39.36066892455921)
# POINT (20.024580550436863 39.36066892455921)
# POINT (20.026180550436862 39.36066892455921)
# POINT (20.027780550436862 39.36066892455921)
# POINT (20.029380550436862 39.36066892455921)
# POINT (20.030980550436862 39.36066892455921)
# POINT (20.03258055043686 39.36066892455921)
# POINT (20.03418055043686 39.36066892455921)
# POINT (20.03578055043686 39.36066892455921)
# POINT (20.03738055043686 39.36066892455921)
# POINT (20.03898055043686 39.36066892455921)
# POINT (20.04058055043686 39.36066892455921)
# POINT (20.04218055043686 39.36066892455921)
# POINT (20.04378055043686 39.36066892455921)
# POINT (20.04538055043686 39.36066892455921)
# POINT (20.04698055043686 39.36066892455921)
# POINT (20.04858055043686 39.36066892455921)
# POINT (20.05018055043686 39.36066892455921)
# POINT (20.05178055043686 39.36066892455921)
# POINT (20.05338055043686 39.36066892455921)
# POINT (20.05498055043686 39.36066892455921)
# POINT (20.05658055043686 39.36066892455921)
# POINT (20.05818055043686 39.36066892455921)
# POINT (20.05978055043686 39.36066892455921)
# POINT (20.06138055043686 39.36066892455921)
# POINT (20.06298055043686 39.36066892455921)
# POINT (20.064580550436858 39.36066892455921)
# POINT (20.066180550436858 39.36066892455921)
# POINT (20.067780550436858 39.36066892455921)
# POINT (20.069380550436858 39.36066892455921)
# POINT (20.070980550436857 39.36066892455921)
# POINT (20.072580550436857 39.36066892455921)
# POINT (20.074180550436857 39.36066892455921)
# POINT (20.075780550436857 39.36066892455921)
# POINT (20.077380550436857 39.36066892455921)
# POINT (20.078980550436857 39.36066892455921)
# POINT (20.080580550436856 39.36066892455921)
# POINT (20.082180550436856 39.36066892455921)
# POINT (20.083780550436856 39.36066892455921)
# POINT (20.085380550436856 39.36066892455921)
# POINT (20.086980550436856 39.36066892455921)
# POINT (20.088580550436856 39.36066892455921)
# POINT (20.090180550436855 39.36066892455921)
# POINT (20.091780550436855 39.36066892455921)
# POINT (20.093380550436855 39.36066892455921)
# POINT (20.094980550436855 39.36066892455921)
# POINT (20.096580550436855 39.36066892455921)
# POINT (20.098180550436854 39.36066892455921)
# POINT (20.099780550436854 39.36066892455921)
# POINT (20.101380550436854 39.36066892455921)
# POINT (20.102980550436854 39.36066892455921)
# POINT (20.104580550436854 39.36066892455921)
# POINT (20.106180550436854 39.36066892455921)
# POINT (20.107780550436853 39.36066892455921)
# POINT (20.109380550436853 39.36066892455921)
# POINT (20.110980550436853 39.36066892455921)
# POINT (20.112580550436853 39.36066892455921)
# POINT (20.114180550436853 39.36066892455921)
# POINT (20.115780550436853 39.36066892455921)
# POINT (20.117380550436852 39.36066892455921)
# POINT (20.118980550436852 39.36066892455921)
# POINT (20.120580550436852 39.36066892455921)
# POINT (20.122180550436852 39.36066892455921)
# POINT (19.629380550436906 39.361868924559204)
# POINT (19.630980550436906 39.361868924559204)
# POINT (19.632580550436906 39.361868924559204)
# POINT (19.634180550436906 39.361868924559204)
# POINT (19.635780550436905 39.361868924559204)
# POINT (19.637380550436905 39.361868924559204)
# POINT (19.638980550436905 39.361868924559204)
# POINT (19.640580550436905 39.361868924559204)
# POINT (19.642180550436905 39.361868924559204)
# POINT (19.643780550436905 39.361868924559204)
# POINT (19.645380550436904 39.361868924559204)
# POINT (19.646980550436904 39.361868924559204)
# POINT (19.648580550436904 39.361868924559204)
# POINT (19.650180550436904 39.361868924559204)
# POINT (19.651780550436904 39.361868924559204)
# POINT (19.653380550436903 39.361868924559204)
# POINT (19.654980550436903 39.361868924559204)
# POINT (19.656580550436903 39.361868924559204)
# POINT (19.658180550436903 39.361868924559204)
# POINT (19.659780550436903 39.361868924559204)
# POINT (19.661380550436903 39.361868924559204)
# POINT (19.662980550436902 39.361868924559204)
# POINT (19.664580550436902 39.361868924559204)
# POINT (19.666180550436902 39.361868924559204)
# POINT (19.667780550436902 39.361868924559204)
# POINT (19.6693805504369 39.361868924559204)
# POINT (19.6709805504369 39.361868924559204)
# POINT (19.6725805504369 39.361868924559204)
# POINT (19.6741805504369 39.361868924559204)
# POINT (19.6757805504369 39.361868924559204)
# POINT (19.6773805504369 39.361868924559204)
# POINT (19.6789805504369 39.361868924559204)
# POINT (19.6805805504369 39.361868924559204)
# POINT (19.6821805504369 39.361868924559204)
# POINT (19.6837805504369 39.361868924559204)
# POINT (19.6853805504369 39.361868924559204)
# POINT (19.6869805504369 39.361868924559204)
# POINT (19.6885805504369 39.361868924559204)
# POINT (19.6901805504369 39.361868924559204)
# POINT (19.6917805504369 39.361868924559204)
# POINT (19.6933805504369 39.361868924559204)
# POINT (19.6949805504369 39.361868924559204)
# POINT (19.6965805504369 39.361868924559204)
# POINT (19.6981805504369 39.361868924559204)
# POINT (19.6997805504369 39.361868924559204)
# POINT (19.701380550436898 39.361868924559204)
# POINT (19.702980550436898 39.361868924559204)
# POINT (19.704580550436898 39.361868924559204)
# POINT (19.706180550436898 39.361868924559204)
# POINT (19.707780550436897 39.361868924559204)
# POINT (19.709380550436897 39.361868924559204)
# POINT (19.710980550436897 39.361868924559204)
# POINT (19.712580550436897 39.361868924559204)
# POINT (19.714180550436897 39.361868924559204)
# POINT (19.715780550436897 39.361868924559204)
# POINT (19.717380550436896 39.361868924559204)
# POINT (19.718980550436896 39.361868924559204)
# POINT (19.720580550436896 39.361868924559204)
# POINT (19.722180550436896 39.361868924559204)
# POINT (19.723780550436896 39.361868924559204)
# POINT (19.725380550436896 39.361868924559204)
# POINT (19.726980550436895 39.361868924559204)
# POINT (19.728580550436895 39.361868924559204)
# POINT (19.730180550436895 39.361868924559204)
# POINT (19.731780550436895 39.361868924559204)
# POINT (19.733380550436895 39.361868924559204)
# POINT (19.734980550436894 39.361868924559204)
# POINT (19.736580550436894 39.361868924559204)
# POINT (19.738180550436894 39.361868924559204)
# POINT (19.739780550436894 39.361868924559204)
# POINT (19.741380550436894 39.361868924559204)
# POINT (19.742980550436894 39.361868924559204)
# POINT (19.744580550436893 39.361868924559204)
# POINT (19.746180550436893 39.361868924559204)
# POINT (19.747780550436893 39.361868924559204)
# POINT (19.749380550436893 39.361868924559204)
# POINT (19.750980550436893 39.361868924559204)
# POINT (19.752580550436893 39.361868924559204)
# POINT (19.754180550436892 39.361868924559204)
# POINT (19.755780550436892 39.361868924559204)
# POINT (19.757380550436892 39.361868924559204)
# POINT (19.758980550436892 39.361868924559204)
# POINT (19.76058055043689 39.361868924559204)
# POINT (19.76218055043689 39.361868924559204)
# POINT (19.76378055043689 39.361868924559204)
# POINT (19.76538055043689 39.361868924559204)
# POINT (19.76698055043689 39.361868924559204)
# POINT (19.76858055043689 39.361868924559204)
# POINT (19.77018055043689 39.361868924559204)
# POINT (19.77178055043689 39.361868924559204)
# POINT (19.77338055043689 39.361868924559204)
# POINT (19.77498055043689 39.361868924559204)
# POINT (19.77658055043689 39.361868924559204)
# POINT (19.77818055043689 39.361868924559204)
# POINT (19.77978055043689 39.361868924559204)
# POINT (19.78138055043689 39.361868924559204)
# POINT (19.78298055043689 39.361868924559204)
# POINT (19.78458055043689 39.361868924559204)
# POINT (19.78618055043689 39.361868924559204)
# POINT (19.78778055043689 39.361868924559204)
# POINT (19.78938055043689 39.361868924559204)
# POINT (19.79098055043689 39.361868924559204)
# POINT (19.792580550436888 39.361868924559204)
# POINT (19.794180550436888 39.361868924559204)
# POINT (19.795780550436888 39.361868924559204)
# POINT (19.797380550436888 39.361868924559204)
# POINT (19.798980550436887 39.361868924559204)
# POINT (19.800580550436887 39.361868924559204)
# POINT (19.802180550436887 39.361868924559204)
# POINT (19.803780550436887 39.361868924559204)
# POINT (19.805380550436887 39.361868924559204)
# POINT (19.806980550436887 39.361868924559204)
# POINT (19.808580550436886 39.361868924559204)
# POINT (19.810180550436886 39.361868924559204)
# POINT (19.811780550436886 39.361868924559204)
# POINT (19.813380550436886 39.361868924559204)
# POINT (19.814980550436886 39.361868924559204)
# POINT (19.816580550436885 39.361868924559204)
# POINT (19.818180550436885 39.361868924559204)
# POINT (19.819780550436885 39.361868924559204)
# POINT (19.821380550436885 39.361868924559204)
# POINT (19.822980550436885 39.361868924559204)
# POINT (19.824580550436885 39.361868924559204)
# POINT (19.826180550436884 39.361868924559204)
# POINT (19.827780550436884 39.361868924559204)
# POINT (19.829380550436884 39.361868924559204)
# POINT (19.830980550436884 39.361868924559204)
# POINT (19.832580550436884 39.361868924559204)
# POINT (19.834180550436884 39.361868924559204)
# POINT (19.835780550436883 39.361868924559204)
# POINT (19.837380550436883 39.361868924559204)
# POINT (19.838980550436883 39.361868924559204)
# POINT (19.840580550436883 39.361868924559204)
# POINT (19.842180550436883 39.361868924559204)
# POINT (19.843780550436882 39.361868924559204)
# POINT (19.845380550436882 39.361868924559204)
# POINT (19.846980550436882 39.361868924559204)
# POINT (19.848580550436882 39.361868924559204)
# POINT (19.850180550436882 39.361868924559204)
# POINT (19.85178055043688 39.361868924559204)
# POINT (19.85338055043688 39.361868924559204)
# POINT (19.85498055043688 39.361868924559204)
# POINT (19.85658055043688 39.361868924559204)
# POINT (19.85818055043688 39.361868924559204)
# POINT (19.85978055043688 39.361868924559204)
# POINT (19.86138055043688 39.361868924559204)
# POINT (19.86298055043688 39.361868924559204)
# POINT (19.86458055043688 39.361868924559204)
# POINT (19.86618055043688 39.361868924559204)
# POINT (19.86778055043688 39.361868924559204)
# POINT (19.86938055043688 39.361868924559204)
# POINT (19.87098055043688 39.361868924559204)
# POINT (19.87258055043688 39.361868924559204)
# POINT (19.87418055043688 39.361868924559204)
# POINT (19.87578055043688 39.361868924559204)
# POINT (19.87738055043688 39.361868924559204)
# POINT (19.87898055043688 39.361868924559204)
# POINT (19.88058055043688 39.361868924559204)
# POINT (19.88218055043688 39.361868924559204)
# POINT (19.883780550436878 39.361868924559204)
# POINT (19.885380550436878 39.361868924559204)
# POINT (19.886980550436878 39.361868924559204)
# POINT (19.888580550436878 39.361868924559204)
# POINT (19.890180550436877 39.361868924559204)
# POINT (19.891780550436877 39.361868924559204)
# POINT (19.893380550436877 39.361868924559204)
# POINT (19.894980550436877 39.361868924559204)
# POINT (19.896580550436877 39.361868924559204)
# POINT (19.898180550436877 39.361868924559204)
# POINT (19.899780550436876 39.361868924559204)
# POINT (19.901380550436876 39.361868924559204)
# POINT (19.902980550436876 39.361868924559204)
# POINT (19.904580550436876 39.361868924559204)
# POINT (19.906180550436876 39.361868924559204)
# POINT (19.907780550436875 39.361868924559204)
# POINT (19.909380550436875 39.361868924559204)
# POINT (19.910980550436875 39.361868924559204)
# POINT (19.912580550436875 39.361868924559204)
# POINT (19.914180550436875 39.361868924559204)
# POINT (19.915780550436875 39.361868924559204)
# POINT (19.917380550436874 39.361868924559204)
# POINT (19.918980550436874 39.361868924559204)
# POINT (19.920580550436874 39.361868924559204)
# POINT (19.922180550436874 39.361868924559204)
# POINT (19.923780550436874 39.361868924559204)
# POINT (19.925380550436874 39.361868924559204)
# POINT (19.926980550436873 39.361868924559204)
# POINT (19.928580550436873 39.361868924559204)
# POINT (19.930180550436873 39.361868924559204)
# POINT (19.931780550436873 39.361868924559204)
# POINT (19.933380550436873 39.361868924559204)
# POINT (19.934980550436872 39.361868924559204)
# POINT (19.936580550436872 39.361868924559204)
# POINT (19.938180550436872 39.361868924559204)
# POINT (19.939780550436872 39.361868924559204)
# POINT (19.94138055043687 39.361868924559204)
# POINT (19.94298055043687 39.361868924559204)
# POINT (19.94458055043687 39.361868924559204)
# POINT (19.94618055043687 39.361868924559204)
# POINT (19.94778055043687 39.361868924559204)
# POINT (19.94938055043687 39.361868924559204)
# POINT (19.95098055043687 39.361868924559204)
# POINT (19.95258055043687 39.361868924559204)
# POINT (19.95418055043687 39.361868924559204)
# POINT (19.95578055043687 39.361868924559204)
# POINT (19.95738055043687 39.361868924559204)
# POINT (19.95898055043687 39.361868924559204)
# POINT (19.96058055043687 39.361868924559204)
# POINT (19.96218055043687 39.361868924559204)
# POINT (19.96378055043687 39.361868924559204)
# POINT (19.96538055043687 39.361868924559204)
# POINT (19.96698055043687 39.361868924559204)
# POINT (19.96858055043687 39.361868924559204)
# POINT (19.97018055043687 39.361868924559204)
# POINT (19.97178055043687 39.361868924559204)
# POINT (19.973380550436868 39.361868924559204)
# POINT (19.974980550436868 39.361868924559204)
# POINT (19.976580550436868 39.361868924559204)
# POINT (19.978180550436868 39.361868924559204)
# POINT (19.979780550436868 39.361868924559204)
# POINT (19.981380550436867 39.361868924559204)
# POINT (19.982980550436867 39.361868924559204)
# POINT (19.984580550436867 39.361868924559204)
# POINT (19.986180550436867 39.361868924559204)
# POINT (19.987780550436867 39.361868924559204)
# POINT (19.989380550436866 39.361868924559204)
# POINT (19.990980550436866 39.361868924559204)
# POINT (19.992580550436866 39.361868924559204)
# POINT (19.994180550436866 39.361868924559204)
# POINT (19.995780550436866 39.361868924559204)
# POINT (19.997380550436866 39.361868924559204)
# POINT (19.998980550436865 39.361868924559204)
# POINT (20.000580550436865 39.361868924559204)
# POINT (20.002180550436865 39.361868924559204)
# POINT (20.003780550436865 39.361868924559204)
# POINT (20.005380550436865 39.361868924559204)
# POINT (20.006980550436865 39.361868924559204)
# POINT (20.008580550436864 39.361868924559204)
# POINT (20.010180550436864 39.361868924559204)
# POINT (20.011780550436864 39.361868924559204)
# POINT (20.013380550436864 39.361868924559204)
# POINT (20.014980550436864 39.361868924559204)
# POINT (20.016580550436863 39.361868924559204)
# POINT (20.018180550436863 39.361868924559204)
# POINT (20.019780550436863 39.361868924559204)
# POINT (20.021380550436863 39.361868924559204)
# POINT (20.022980550436863 39.361868924559204)
# POINT (20.024580550436863 39.361868924559204)
# POINT (20.026180550436862 39.361868924559204)
# POINT (20.027780550436862 39.361868924559204)
# POINT (20.029380550436862 39.361868924559204)
# POINT (20.030980550436862 39.361868924559204)
# POINT (20.03258055043686 39.361868924559204)
# POINT (20.03418055043686 39.361868924559204)
# POINT (20.03578055043686 39.361868924559204)
# POINT (20.03738055043686 39.361868924559204)
# POINT (20.03898055043686 39.361868924559204)
# POINT (20.04058055043686 39.361868924559204)
# POINT (20.04218055043686 39.361868924559204)
# POINT (20.04378055043686 39.361868924559204)
# POINT (20.04538055043686 39.361868924559204)
# POINT (20.04698055043686 39.361868924559204)
# POINT (20.04858055043686 39.361868924559204)
# POINT (20.05018055043686 39.361868924559204)
# POINT (20.05178055043686 39.361868924559204)
# POINT (20.05338055043686 39.361868924559204)
# POINT (20.05498055043686 39.361868924559204)
# POINT (20.05658055043686 39.361868924559204)
# POINT (20.05818055043686 39.361868924559204)
# POINT (20.05978055043686 39.361868924559204)
# POINT (20.06138055043686 39.361868924559204)
# POINT (20.06298055043686 39.361868924559204)
# POINT (20.064580550436858 39.361868924559204)
# POINT (20.066180550436858 39.361868924559204)
# POINT (20.067780550436858 39.361868924559204)
# POINT (20.069380550436858 39.361868924559204)
# POINT (20.070980550436857 39.361868924559204)
# POINT (20.072580550436857 39.361868924559204)
# POINT (20.074180550436857 39.361868924559204)
# POINT (20.075780550436857 39.361868924559204)
# POINT (20.077380550436857 39.361868924559204)
# POINT (20.078980550436857 39.361868924559204)
# POINT (20.080580550436856 39.361868924559204)
# POINT (20.082180550436856 39.361868924559204)
# POINT (20.083780550436856 39.361868924559204)
# POINT (20.085380550436856 39.361868924559204)
# POINT (20.086980550436856 39.361868924559204)
# POINT (20.088580550436856 39.361868924559204)
# POINT (20.090180550436855 39.361868924559204)
# POINT (20.091780550436855 39.361868924559204)
# POINT (20.093380550436855 39.361868924559204)
# POINT (20.094980550436855 39.361868924559204)
# POINT (20.096580550436855 39.361868924559204)
# POINT (20.098180550436854 39.361868924559204)
# POINT (20.099780550436854 39.361868924559204)
# POINT (20.101380550436854 39.361868924559204)
# POINT (20.102980550436854 39.361868924559204)
# POINT (20.104580550436854 39.361868924559204)
# POINT (20.106180550436854 39.361868924559204)
# POINT (20.107780550436853 39.361868924559204)
# POINT (20.109380550436853 39.361868924559204)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.110980550436853 39.361868924559204)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.112580550436853 39.361868924559204)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.114180550436853 39.361868924559204)
# POINT (20.115780550436853 39.361868924559204)
# POINT (20.117380550436852 39.361868924559204)
# POINT (20.118980550436852 39.361868924559204)
# POINT (20.120580550436852 39.361868924559204)
# POINT (20.122180550436852 39.361868924559204)
# POINT (19.629380550436906 39.3630689245592)
# POINT (19.630980550436906 39.3630689245592)
# POINT (19.632580550436906 39.3630689245592)
# POINT (19.634180550436906 39.3630689245592)
# POINT (19.635780550436905 39.3630689245592)
# POINT (19.637380550436905 39.3630689245592)
# POINT (19.638980550436905 39.3630689245592)
# POINT (19.640580550436905 39.3630689245592)
# POINT (19.642180550436905 39.3630689245592)
# POINT (19.643780550436905 39.3630689245592)
# POINT (19.645380550436904 39.3630689245592)
# POINT (19.646980550436904 39.3630689245592)
# POINT (19.648580550436904 39.3630689245592)
# POINT (19.650180550436904 39.3630689245592)
# POINT (19.651780550436904 39.3630689245592)
# POINT (19.653380550436903 39.3630689245592)
# POINT (19.654980550436903 39.3630689245592)
# POINT (19.656580550436903 39.3630689245592)
# POINT (19.658180550436903 39.3630689245592)
# POINT (19.659780550436903 39.3630689245592)
# POINT (19.661380550436903 39.3630689245592)
# POINT (19.662980550436902 39.3630689245592)
# POINT (19.664580550436902 39.3630689245592)
# POINT (19.666180550436902 39.3630689245592)
# POINT (19.667780550436902 39.3630689245592)
# POINT (19.6693805504369 39.3630689245592)
# POINT (19.6709805504369 39.3630689245592)
# POINT (19.6725805504369 39.3630689245592)
# POINT (19.6741805504369 39.3630689245592)
# POINT (19.6757805504369 39.3630689245592)
# POINT (19.6773805504369 39.3630689245592)
# POINT (19.6789805504369 39.3630689245592)
# POINT (19.6805805504369 39.3630689245592)
# POINT (19.6821805504369 39.3630689245592)
# POINT (19.6837805504369 39.3630689245592)
# POINT (19.6853805504369 39.3630689245592)
# POINT (19.6869805504369 39.3630689245592)
# POINT (19.6885805504369 39.3630689245592)
# POINT (19.6901805504369 39.3630689245592)
# POINT (19.6917805504369 39.3630689245592)
# POINT (19.6933805504369 39.3630689245592)
# POINT (19.6949805504369 39.3630689245592)
# POINT (19.6965805504369 39.3630689245592)
# POINT (19.6981805504369 39.3630689245592)
# POINT (19.6997805504369 39.3630689245592)
# POINT (19.701380550436898 39.3630689245592)
# POINT (19.702980550436898 39.3630689245592)
# POINT (19.704580550436898 39.3630689245592)
# POINT (19.706180550436898 39.3630689245592)
# POINT (19.707780550436897 39.3630689245592)
# POINT (19.709380550436897 39.3630689245592)
# POINT (19.710980550436897 39.3630689245592)
# POINT (19.712580550436897 39.3630689245592)
# POINT (19.714180550436897 39.3630689245592)
# POINT (19.715780550436897 39.3630689245592)
# POINT (19.717380550436896 39.3630689245592)
# POINT (19.718980550436896 39.3630689245592)
# POINT (19.720580550436896 39.3630689245592)
# POINT (19.722180550436896 39.3630689245592)
# POINT (19.723780550436896 39.3630689245592)
# POINT (19.725380550436896 39.3630689245592)
# POINT (19.726980550436895 39.3630689245592)
# POINT (19.728580550436895 39.3630689245592)
# POINT (19.730180550436895 39.3630689245592)
# POINT (19.731780550436895 39.3630689245592)
# POINT (19.733380550436895 39.3630689245592)
# POINT (19.734980550436894 39.3630689245592)
# POINT (19.736580550436894 39.3630689245592)
# POINT (19.738180550436894 39.3630689245592)
# POINT (19.739780550436894 39.3630689245592)
# POINT (19.741380550436894 39.3630689245592)
# POINT (19.742980550436894 39.3630689245592)
# POINT (19.744580550436893 39.3630689245592)
# POINT (19.746180550436893 39.3630689245592)
# POINT (19.747780550436893 39.3630689245592)
# POINT (19.749380550436893 39.3630689245592)
# POINT (19.750980550436893 39.3630689245592)
# POINT (19.752580550436893 39.3630689245592)
# POINT (19.754180550436892 39.3630689245592)
# POINT (19.755780550436892 39.3630689245592)
# POINT (19.757380550436892 39.3630689245592)
# POINT (19.758980550436892 39.3630689245592)
# POINT (19.76058055043689 39.3630689245592)
# POINT (19.76218055043689 39.3630689245592)
# POINT (19.76378055043689 39.3630689245592)
# POINT (19.76538055043689 39.3630689245592)
# POINT (19.76698055043689 39.3630689245592)
# POINT (19.76858055043689 39.3630689245592)
# POINT (19.77018055043689 39.3630689245592)
# POINT (19.77178055043689 39.3630689245592)
# POINT (19.77338055043689 39.3630689245592)
# POINT (19.77498055043689 39.3630689245592)
# POINT (19.77658055043689 39.3630689245592)
# POINT (19.77818055043689 39.3630689245592)
# POINT (19.77978055043689 39.3630689245592)
# POINT (19.78138055043689 39.3630689245592)
# POINT (19.78298055043689 39.3630689245592)
# POINT (19.78458055043689 39.3630689245592)
# POINT (19.78618055043689 39.3630689245592)
# POINT (19.78778055043689 39.3630689245592)
# POINT (19.78938055043689 39.3630689245592)
# POINT (19.79098055043689 39.3630689245592)
# POINT (19.792580550436888 39.3630689245592)
# POINT (19.794180550436888 39.3630689245592)
# POINT (19.795780550436888 39.3630689245592)
# POINT (19.797380550436888 39.3630689245592)
# POINT (19.798980550436887 39.3630689245592)
# POINT (19.800580550436887 39.3630689245592)
# POINT (19.802180550436887 39.3630689245592)
# POINT (19.803780550436887 39.3630689245592)
# POINT (19.805380550436887 39.3630689245592)
# POINT (19.806980550436887 39.3630689245592)
# POINT (19.808580550436886 39.3630689245592)
# POINT (19.810180550436886 39.3630689245592)
# POINT (19.811780550436886 39.3630689245592)
# POINT (19.813380550436886 39.3630689245592)
# POINT (19.814980550436886 39.3630689245592)
# POINT (19.816580550436885 39.3630689245592)
# POINT (19.818180550436885 39.3630689245592)
# POINT (19.819780550436885 39.3630689245592)
# POINT (19.821380550436885 39.3630689245592)
# POINT (19.822980550436885 39.3630689245592)
# POINT (19.824580550436885 39.3630689245592)
# POINT (19.826180550436884 39.3630689245592)
# POINT (19.827780550436884 39.3630689245592)
# POINT (19.829380550436884 39.3630689245592)
# POINT (19.830980550436884 39.3630689245592)
# POINT (19.832580550436884 39.3630689245592)
# POINT (19.834180550436884 39.3630689245592)
# POINT (19.835780550436883 39.3630689245592)
# POINT (19.837380550436883 39.3630689245592)
# POINT (19.838980550436883 39.3630689245592)
# POINT (19.840580550436883 39.3630689245592)
# POINT (19.842180550436883 39.3630689245592)
# POINT (19.843780550436882 39.3630689245592)
# POINT (19.845380550436882 39.3630689245592)
# POINT (19.846980550436882 39.3630689245592)
# POINT (19.848580550436882 39.3630689245592)
# POINT (19.850180550436882 39.3630689245592)
# POINT (19.85178055043688 39.3630689245592)
# POINT (19.85338055043688 39.3630689245592)
# POINT (19.85498055043688 39.3630689245592)
# POINT (19.85658055043688 39.3630689245592)
# POINT (19.85818055043688 39.3630689245592)
# POINT (19.85978055043688 39.3630689245592)
# POINT (19.86138055043688 39.3630689245592)
# POINT (19.86298055043688 39.3630689245592)
# POINT (19.86458055043688 39.3630689245592)
# POINT (19.86618055043688 39.3630689245592)
# POINT (19.86778055043688 39.3630689245592)
# POINT (19.86938055043688 39.3630689245592)
# POINT (19.87098055043688 39.3630689245592)
# POINT (19.87258055043688 39.3630689245592)
# POINT (19.87418055043688 39.3630689245592)
# POINT (19.87578055043688 39.3630689245592)
# POINT (19.87738055043688 39.3630689245592)
# POINT (19.87898055043688 39.3630689245592)
# POINT (19.88058055043688 39.3630689245592)
# POINT (19.88218055043688 39.3630689245592)
# POINT (19.883780550436878 39.3630689245592)
# POINT (19.885380550436878 39.3630689245592)
# POINT (19.886980550436878 39.3630689245592)
# POINT (19.888580550436878 39.3630689245592)
# POINT (19.890180550436877 39.3630689245592)
# POINT (19.891780550436877 39.3630689245592)
# POINT (19.893380550436877 39.3630689245592)
# POINT (19.894980550436877 39.3630689245592)
# POINT (19.896580550436877 39.3630689245592)
# POINT (19.898180550436877 39.3630689245592)
# POINT (19.899780550436876 39.3630689245592)
# POINT (19.901380550436876 39.3630689245592)
# POINT (19.902980550436876 39.3630689245592)
# POINT (19.904580550436876 39.3630689245592)
# POINT (19.906180550436876 39.3630689245592)
# POINT (19.907780550436875 39.3630689245592)
# POINT (19.909380550436875 39.3630689245592)
# POINT (19.910980550436875 39.3630689245592)
# POINT (19.912580550436875 39.3630689245592)
# POINT (19.914180550436875 39.3630689245592)
# POINT (19.915780550436875 39.3630689245592)
# POINT (19.917380550436874 39.3630689245592)
# POINT (19.918980550436874 39.3630689245592)
# POINT (19.920580550436874 39.3630689245592)
# POINT (19.922180550436874 39.3630689245592)
# POINT (19.923780550436874 39.3630689245592)
# POINT (19.925380550436874 39.3630689245592)
# POINT (19.926980550436873 39.3630689245592)
# POINT (19.928580550436873 39.3630689245592)
# POINT (19.930180550436873 39.3630689245592)
# POINT (19.931780550436873 39.3630689245592)
# POINT (19.933380550436873 39.3630689245592)
# POINT (19.934980550436872 39.3630689245592)
# POINT (19.936580550436872 39.3630689245592)
# POINT (19.938180550436872 39.3630689245592)
# POINT (19.939780550436872 39.3630689245592)
# POINT (19.94138055043687 39.3630689245592)
# POINT (19.94298055043687 39.3630689245592)
# POINT (19.94458055043687 39.3630689245592)
# POINT (19.94618055043687 39.3630689245592)
# POINT (19.94778055043687 39.3630689245592)
# POINT (19.94938055043687 39.3630689245592)
# POINT (19.95098055043687 39.3630689245592)
# POINT (19.95258055043687 39.3630689245592)
# POINT (19.95418055043687 39.3630689245592)
# POINT (19.95578055043687 39.3630689245592)
# POINT (19.95738055043687 39.3630689245592)
# POINT (19.95898055043687 39.3630689245592)
# POINT (19.96058055043687 39.3630689245592)
# POINT (19.96218055043687 39.3630689245592)
# POINT (19.96378055043687 39.3630689245592)
# POINT (19.96538055043687 39.3630689245592)
# POINT (19.96698055043687 39.3630689245592)
# POINT (19.96858055043687 39.3630689245592)
# POINT (19.97018055043687 39.3630689245592)
# POINT (19.97178055043687 39.3630689245592)
# POINT (19.973380550436868 39.3630689245592)
# POINT (19.974980550436868 39.3630689245592)
# POINT (19.976580550436868 39.3630689245592)
# POINT (19.978180550436868 39.3630689245592)
# POINT (19.979780550436868 39.3630689245592)
# POINT (19.981380550436867 39.3630689245592)
# POINT (19.982980550436867 39.3630689245592)
# POINT (19.984580550436867 39.3630689245592)
# POINT (19.986180550436867 39.3630689245592)
# POINT (19.987780550436867 39.3630689245592)
# POINT (19.989380550436866 39.3630689245592)
# POINT (19.990980550436866 39.3630689245592)
# POINT (19.992580550436866 39.3630689245592)
# POINT (19.994180550436866 39.3630689245592)
# POINT (19.995780550436866 39.3630689245592)
# POINT (19.997380550436866 39.3630689245592)
# POINT (19.998980550436865 39.3630689245592)
# POINT (20.000580550436865 39.3630689245592)
# POINT (20.002180550436865 39.3630689245592)
# POINT (20.003780550436865 39.3630689245592)
# POINT (20.005380550436865 39.3630689245592)
# POINT (20.006980550436865 39.3630689245592)
# POINT (20.008580550436864 39.3630689245592)
# POINT (20.010180550436864 39.3630689245592)
# POINT (20.011780550436864 39.3630689245592)
# POINT (20.013380550436864 39.3630689245592)
# POINT (20.014980550436864 39.3630689245592)
# POINT (20.016580550436863 39.3630689245592)
# POINT (20.018180550436863 39.3630689245592)
# POINT (20.019780550436863 39.3630689245592)
# POINT (20.021380550436863 39.3630689245592)
# POINT (20.022980550436863 39.3630689245592)
# POINT (20.024580550436863 39.3630689245592)
# POINT (20.026180550436862 39.3630689245592)
# POINT (20.027780550436862 39.3630689245592)
# POINT (20.029380550436862 39.3630689245592)
# POINT (20.030980550436862 39.3630689245592)
# POINT (20.03258055043686 39.3630689245592)
# POINT (20.03418055043686 39.3630689245592)
# POINT (20.03578055043686 39.3630689245592)
# POINT (20.03738055043686 39.3630689245592)
# POINT (20.03898055043686 39.3630689245592)
# POINT (20.04058055043686 39.3630689245592)
# POINT (20.04218055043686 39.3630689245592)
# POINT (20.04378055043686 39.3630689245592)
# POINT (20.04538055043686 39.3630689245592)
# POINT (20.04698055043686 39.3630689245592)
# POINT (20.04858055043686 39.3630689245592)
# POINT (20.05018055043686 39.3630689245592)
# POINT (20.05178055043686 39.3630689245592)
# POINT (20.05338055043686 39.3630689245592)
# POINT (20.05498055043686 39.3630689245592)
# POINT (20.05658055043686 39.3630689245592)
# POINT (20.05818055043686 39.3630689245592)
# POINT (20.05978055043686 39.3630689245592)
# POINT (20.06138055043686 39.3630689245592)
# POINT (20.06298055043686 39.3630689245592)
# POINT (20.064580550436858 39.3630689245592)
# POINT (20.066180550436858 39.3630689245592)
# POINT (20.067780550436858 39.3630689245592)
# POINT (20.069380550436858 39.3630689245592)
# POINT (20.070980550436857 39.3630689245592)
# POINT (20.072580550436857 39.3630689245592)
# POINT (20.074180550436857 39.3630689245592)
# POINT (20.075780550436857 39.3630689245592)
# POINT (20.077380550436857 39.3630689245592)
# POINT (20.078980550436857 39.3630689245592)
# POINT (20.080580550436856 39.3630689245592)
# POINT (20.082180550436856 39.3630689245592)
# POINT (20.083780550436856 39.3630689245592)
# POINT (20.085380550436856 39.3630689245592)
# POINT (20.086980550436856 39.3630689245592)
# POINT (20.088580550436856 39.3630689245592)
# POINT (20.090180550436855 39.3630689245592)
# POINT (20.091780550436855 39.3630689245592)
# POINT (20.093380550436855 39.3630689245592)
# POINT (20.094980550436855 39.3630689245592)
# POINT (20.096580550436855 39.3630689245592)
# POINT (20.098180550436854 39.3630689245592)
# POINT (20.099780550436854 39.3630689245592)
# POINT (20.101380550436854 39.3630689245592)
# POINT (20.102980550436854 39.3630689245592)
# POINT (20.104580550436854 39.3630689245592)
# POINT (20.106180550436854 39.3630689245592)
# POINT (20.107780550436853 39.3630689245592)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.109380550436853 39.3630689245592)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.110980550436853 39.3630689245592)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.112580550436853 39.3630689245592)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.114180550436853 39.3630689245592)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.115780550436853 39.3630689245592)
# POINT (20.117380550436852 39.3630689245592)
# POINT (20.118980550436852 39.3630689245592)
# POINT (20.120580550436852 39.3630689245592)
# POINT (20.122180550436852 39.3630689245592)
# POINT (19.629380550436906 39.3642689245592)
# POINT (19.630980550436906 39.3642689245592)
# POINT (19.632580550436906 39.3642689245592)
# POINT (19.634180550436906 39.3642689245592)
# POINT (19.635780550436905 39.3642689245592)
# POINT (19.637380550436905 39.3642689245592)
# POINT (19.638980550436905 39.3642689245592)
# POINT (19.640580550436905 39.3642689245592)
# POINT (19.642180550436905 39.3642689245592)
# POINT (19.643780550436905 39.3642689245592)
# POINT (19.645380550436904 39.3642689245592)
# POINT (19.646980550436904 39.3642689245592)
# POINT (19.648580550436904 39.3642689245592)
# POINT (19.650180550436904 39.3642689245592)
# POINT (19.651780550436904 39.3642689245592)
# POINT (19.653380550436903 39.3642689245592)
# POINT (19.654980550436903 39.3642689245592)
# POINT (19.656580550436903 39.3642689245592)
# POINT (19.658180550436903 39.3642689245592)
# POINT (19.659780550436903 39.3642689245592)
# POINT (19.661380550436903 39.3642689245592)
# POINT (19.662980550436902 39.3642689245592)
# POINT (19.664580550436902 39.3642689245592)
# POINT (19.666180550436902 39.3642689245592)
# POINT (19.667780550436902 39.3642689245592)
# POINT (19.6693805504369 39.3642689245592)
# POINT (19.6709805504369 39.3642689245592)
# POINT (19.6725805504369 39.3642689245592)
# POINT (19.6741805504369 39.3642689245592)
# POINT (19.6757805504369 39.3642689245592)
# POINT (19.6773805504369 39.3642689245592)
# POINT (19.6789805504369 39.3642689245592)
# POINT (19.6805805504369 39.3642689245592)
# POINT (19.6821805504369 39.3642689245592)
# POINT (19.6837805504369 39.3642689245592)
# POINT (19.6853805504369 39.3642689245592)
# POINT (19.6869805504369 39.3642689245592)
# POINT (19.6885805504369 39.3642689245592)
# POINT (19.6901805504369 39.3642689245592)
# POINT (19.6917805504369 39.3642689245592)
# POINT (19.6933805504369 39.3642689245592)
# POINT (19.6949805504369 39.3642689245592)
# POINT (19.6965805504369 39.3642689245592)
# POINT (19.6981805504369 39.3642689245592)
# POINT (19.6997805504369 39.3642689245592)
# POINT (19.701380550436898 39.3642689245592)
# POINT (19.702980550436898 39.3642689245592)
# POINT (19.704580550436898 39.3642689245592)
# POINT (19.706180550436898 39.3642689245592)
# POINT (19.707780550436897 39.3642689245592)
# POINT (19.709380550436897 39.3642689245592)
# POINT (19.710980550436897 39.3642689245592)
# POINT (19.712580550436897 39.3642689245592)
# POINT (19.714180550436897 39.3642689245592)
# POINT (19.715780550436897 39.3642689245592)
# POINT (19.717380550436896 39.3642689245592)
# POINT (19.718980550436896 39.3642689245592)
# POINT (19.720580550436896 39.3642689245592)
# POINT (19.722180550436896 39.3642689245592)
# POINT (19.723780550436896 39.3642689245592)
# POINT (19.725380550436896 39.3642689245592)
# POINT (19.726980550436895 39.3642689245592)
# POINT (19.728580550436895 39.3642689245592)
# POINT (19.730180550436895 39.3642689245592)
# POINT (19.731780550436895 39.3642689245592)
# POINT (19.733380550436895 39.3642689245592)
# POINT (19.734980550436894 39.3642689245592)
# POINT (19.736580550436894 39.3642689245592)
# POINT (19.738180550436894 39.3642689245592)
# POINT (19.739780550436894 39.3642689245592)
# POINT (19.741380550436894 39.3642689245592)
# POINT (19.742980550436894 39.3642689245592)
# POINT (19.744580550436893 39.3642689245592)
# POINT (19.746180550436893 39.3642689245592)
# POINT (19.747780550436893 39.3642689245592)
# POINT (19.749380550436893 39.3642689245592)
# POINT (19.750980550436893 39.3642689245592)
# POINT (19.752580550436893 39.3642689245592)
# POINT (19.754180550436892 39.3642689245592)
# POINT (19.755780550436892 39.3642689245592)
# POINT (19.757380550436892 39.3642689245592)
# POINT (19.758980550436892 39.3642689245592)
# POINT (19.76058055043689 39.3642689245592)
# POINT (19.76218055043689 39.3642689245592)
# POINT (19.76378055043689 39.3642689245592)
# POINT (19.76538055043689 39.3642689245592)
# POINT (19.76698055043689 39.3642689245592)
# POINT (19.76858055043689 39.3642689245592)
# POINT (19.77018055043689 39.3642689245592)
# POINT (19.77178055043689 39.3642689245592)
# POINT (19.77338055043689 39.3642689245592)
# POINT (19.77498055043689 39.3642689245592)
# POINT (19.77658055043689 39.3642689245592)
# POINT (19.77818055043689 39.3642689245592)
# POINT (19.77978055043689 39.3642689245592)
# POINT (19.78138055043689 39.3642689245592)
# POINT (19.78298055043689 39.3642689245592)
# POINT (19.78458055043689 39.3642689245592)
# POINT (19.78618055043689 39.3642689245592)
# POINT (19.78778055043689 39.3642689245592)
# POINT (19.78938055043689 39.3642689245592)
# POINT (19.79098055043689 39.3642689245592)
# POINT (19.792580550436888 39.3642689245592)
# POINT (19.794180550436888 39.3642689245592)
# POINT (19.795780550436888 39.3642689245592)
# POINT (19.797380550436888 39.3642689245592)
# POINT (19.798980550436887 39.3642689245592)
# POINT (19.800580550436887 39.3642689245592)
# POINT (19.802180550436887 39.3642689245592)
# POINT (19.803780550436887 39.3642689245592)
# POINT (19.805380550436887 39.3642689245592)
# POINT (19.806980550436887 39.3642689245592)
# POINT (19.808580550436886 39.3642689245592)
# POINT (19.810180550436886 39.3642689245592)
# POINT (19.811780550436886 39.3642689245592)
# POINT (19.813380550436886 39.3642689245592)
# POINT (19.814980550436886 39.3642689245592)
# POINT (19.816580550436885 39.3642689245592)
# POINT (19.818180550436885 39.3642689245592)
# POINT (19.819780550436885 39.3642689245592)
# POINT (19.821380550436885 39.3642689245592)
# POINT (19.822980550436885 39.3642689245592)
# POINT (19.824580550436885 39.3642689245592)
# POINT (19.826180550436884 39.3642689245592)
# ...
# POINT (19.646980550436904 39.387068924559145)
# POINT (19.648580550436904 39.387068924559145)
# POINT (19.650180550436904 39.387068924559145)
# POINT (19.651780550436904 39.387068924559145)
# POINT (19.653380550436903 39.387068924559145)
# POINT (19.654980550436903 39.387068924559145)
# POINT (19.656580550436903 39.387068924559145)
# POINT (19.658180550436903 39.387068924559145)
# POINT (19.659780550436903 39.387068924559145)
# POINT (19.661380550436903 39.387068924559145)
# POINT (19.662980550436902 39.387068924559145)
# POINT (19.664580550436902 39.387068924559145)
# POINT (19.666180550436902 39.387068924559145)
# POINT (19.667780550436902 39.387068924559145)
# POINT (19.6693805504369 39.387068924559145)
# POINT (19.6709805504369 39.387068924559145)
# POINT (19.6725805504369 39.387068924559145)
# POINT (19.6741805504369 39.387068924559145)
# POINT (19.6757805504369 39.387068924559145)
# POINT (19.6773805504369 39.387068924559145)
# POINT (19.6789805504369 39.387068924559145)
# POINT (19.6805805504369 39.387068924559145)
# POINT (19.6821805504369 39.387068924559145)
# POINT (19.6837805504369 39.387068924559145)
# POINT (19.6853805504369 39.387068924559145)
# POINT (19.6869805504369 39.387068924559145)
# POINT (19.6885805504369 39.387068924559145)
# POINT (19.6901805504369 39.387068924559145)
# POINT (19.6917805504369 39.387068924559145)
# POINT (19.6933805504369 39.387068924559145)
# POINT (19.6949805504369 39.387068924559145)
# POINT (19.6965805504369 39.387068924559145)
# POINT (19.6981805504369 39.387068924559145)
# POINT (19.6997805504369 39.387068924559145)
# POINT (19.701380550436898 39.387068924559145)
# POINT (19.702980550436898 39.387068924559145)
# POINT (19.704580550436898 39.387068924559145)
# POINT (19.706180550436898 39.387068924559145)
# POINT (19.707780550436897 39.387068924559145)
# POINT (19.709380550436897 39.387068924559145)
# POINT (19.710980550436897 39.387068924559145)
# POINT (19.712580550436897 39.387068924559145)
# POINT (19.714180550436897 39.387068924559145)
# POINT (19.715780550436897 39.387068924559145)
# POINT (19.717380550436896 39.387068924559145)
# POINT (19.718980550436896 39.387068924559145)
# POINT (19.720580550436896 39.387068924559145)
# POINT (19.722180550436896 39.387068924559145)
# POINT (19.723780550436896 39.387068924559145)
# POINT (19.725380550436896 39.387068924559145)
# POINT (19.726980550436895 39.387068924559145)
# POINT (19.728580550436895 39.387068924559145)
# POINT (19.730180550436895 39.387068924559145)
# POINT (19.731780550436895 39.387068924559145)
# POINT (19.733380550436895 39.387068924559145)
# POINT (19.734980550436894 39.387068924559145)
# POINT (19.736580550436894 39.387068924559145)
# POINT (19.738180550436894 39.387068924559145)
# POINT (19.739780550436894 39.387068924559145)
# POINT (19.741380550436894 39.387068924559145)
# POINT (19.742980550436894 39.387068924559145)
# POINT (19.744580550436893 39.387068924559145)
# POINT (19.746180550436893 39.387068924559145)
# POINT (19.747780550436893 39.387068924559145)
# POINT (19.749380550436893 39.387068924559145)
# POINT (19.750980550436893 39.387068924559145)
# POINT (19.752580550436893 39.387068924559145)
# POINT (19.754180550436892 39.387068924559145)
# POINT (19.755780550436892 39.387068924559145)
# POINT (19.757380550436892 39.387068924559145)
# POINT (19.758980550436892 39.387068924559145)
# POINT (19.76058055043689 39.387068924559145)
# POINT (19.76218055043689 39.387068924559145)
# POINT (19.76378055043689 39.387068924559145)
# POINT (19.76538055043689 39.387068924559145)
# POINT (19.76698055043689 39.387068924559145)
# POINT (19.76858055043689 39.387068924559145)
# POINT (19.77018055043689 39.387068924559145)
# POINT (19.77178055043689 39.387068924559145)
# POINT (19.77338055043689 39.387068924559145)
# POINT (19.77498055043689 39.387068924559145)
# POINT (19.77658055043689 39.387068924559145)
# POINT (19.77818055043689 39.387068924559145)
# POINT (19.77978055043689 39.387068924559145)
# POINT (19.78138055043689 39.387068924559145)
# POINT (19.78298055043689 39.387068924559145)
# POINT (19.78458055043689 39.387068924559145)
# POINT (19.78618055043689 39.387068924559145)
# POINT (19.78778055043689 39.387068924559145)
# POINT (19.78938055043689 39.387068924559145)
# POINT (19.79098055043689 39.387068924559145)
# POINT (19.792580550436888 39.387068924559145)
# POINT (19.794180550436888 39.387068924559145)
# POINT (19.795780550436888 39.387068924559145)
# POINT (19.797380550436888 39.387068924559145)
# POINT (19.798980550436887 39.387068924559145)
# POINT (19.800580550436887 39.387068924559145)
# POINT (19.802180550436887 39.387068924559145)
# POINT (19.803780550436887 39.387068924559145)
# POINT (19.805380550436887 39.387068924559145)
# POINT (19.806980550436887 39.387068924559145)
# POINT (19.808580550436886 39.387068924559145)
# POINT (19.810180550436886 39.387068924559145)
# POINT (19.811780550436886 39.387068924559145)
# POINT (19.813380550436886 39.387068924559145)
# POINT (19.814980550436886 39.387068924559145)
# POINT (19.816580550436885 39.387068924559145)
# POINT (19.818180550436885 39.387068924559145)
# POINT (19.819780550436885 39.387068924559145)
# POINT (19.821380550436885 39.387068924559145)
# POINT (19.822980550436885 39.387068924559145)
# POINT (19.824580550436885 39.387068924559145)
# POINT (19.826180550436884 39.387068924559145)
# POINT (19.827780550436884 39.387068924559145)
# POINT (19.829380550436884 39.387068924559145)
# POINT (19.830980550436884 39.387068924559145)
# POINT (19.832580550436884 39.387068924559145)
# POINT (19.834180550436884 39.387068924559145)
# POINT (19.835780550436883 39.387068924559145)
# POINT (19.837380550436883 39.387068924559145)
# POINT (19.838980550436883 39.387068924559145)
# POINT (19.840580550436883 39.387068924559145)
# POINT (19.842180550436883 39.387068924559145)
# POINT (19.843780550436882 39.387068924559145)
# POINT (19.845380550436882 39.387068924559145)
# POINT (19.846980550436882 39.387068924559145)
# POINT (19.848580550436882 39.387068924559145)
# POINT (19.850180550436882 39.387068924559145)
# POINT (19.85178055043688 39.387068924559145)
# POINT (19.85338055043688 39.387068924559145)
# POINT (19.85498055043688 39.387068924559145)
# POINT (19.85658055043688 39.387068924559145)
# POINT (19.85818055043688 39.387068924559145)
# POINT (19.85978055043688 39.387068924559145)
# POINT (19.86138055043688 39.387068924559145)
# POINT (19.86298055043688 39.387068924559145)
# POINT (19.86458055043688 39.387068924559145)
# POINT (19.86618055043688 39.387068924559145)
# POINT (19.86778055043688 39.387068924559145)
# POINT (19.86938055043688 39.387068924559145)
# POINT (19.87098055043688 39.387068924559145)
# POINT (19.87258055043688 39.387068924559145)
# POINT (19.87418055043688 39.387068924559145)
# POINT (19.87578055043688 39.387068924559145)
# POINT (19.87738055043688 39.387068924559145)
# POINT (19.87898055043688 39.387068924559145)
# POINT (19.88058055043688 39.387068924559145)
# POINT (19.88218055043688 39.387068924559145)
# POINT (19.883780550436878 39.387068924559145)
# POINT (19.885380550436878 39.387068924559145)
# POINT (19.886980550436878 39.387068924559145)
# POINT (19.888580550436878 39.387068924559145)
# POINT (19.890180550436877 39.387068924559145)
# POINT (19.891780550436877 39.387068924559145)
# POINT (19.893380550436877 39.387068924559145)
# POINT (19.894980550436877 39.387068924559145)
# POINT (19.896580550436877 39.387068924559145)
# POINT (19.898180550436877 39.387068924559145)
# POINT (19.899780550436876 39.387068924559145)
# POINT (19.901380550436876 39.387068924559145)
# POINT (19.902980550436876 39.387068924559145)
# POINT (19.904580550436876 39.387068924559145)
# POINT (19.906180550436876 39.387068924559145)
# POINT (19.907780550436875 39.387068924559145)
# POINT (19.909380550436875 39.387068924559145)
# POINT (19.910980550436875 39.387068924559145)
# POINT (19.912580550436875 39.387068924559145)
# POINT (19.914180550436875 39.387068924559145)
# POINT (19.915780550436875 39.387068924559145)
# POINT (19.917380550436874 39.387068924559145)
# POINT (19.918980550436874 39.387068924559145)
# POINT (19.920580550436874 39.387068924559145)
# POINT (19.922180550436874 39.387068924559145)
# POINT (19.923780550436874 39.387068924559145)
# POINT (19.925380550436874 39.387068924559145)
# POINT (19.926980550436873 39.387068924559145)
# POINT (19.928580550436873 39.387068924559145)
# POINT (19.930180550436873 39.387068924559145)
# POINT (19.931780550436873 39.387068924559145)
# POINT (19.933380550436873 39.387068924559145)
# POINT (19.934980550436872 39.387068924559145)
# POINT (19.936580550436872 39.387068924559145)
# POINT (19.938180550436872 39.387068924559145)
# POINT (19.939780550436872 39.387068924559145)
# POINT (19.94138055043687 39.387068924559145)
# POINT (19.94298055043687 39.387068924559145)
# POINT (19.94458055043687 39.387068924559145)
# POINT (19.94618055043687 39.387068924559145)
# POINT (19.94778055043687 39.387068924559145)
# POINT (19.94938055043687 39.387068924559145)
# POINT (19.95098055043687 39.387068924559145)
# POINT (19.95258055043687 39.387068924559145)
# POINT (19.95418055043687 39.387068924559145)
# POINT (19.95578055043687 39.387068924559145)
# POINT (19.95738055043687 39.387068924559145)
# POINT (19.95898055043687 39.387068924559145)
# POINT (19.96058055043687 39.387068924559145)
# POINT (19.96218055043687 39.387068924559145)
# POINT (19.96378055043687 39.387068924559145)
# POINT (19.96538055043687 39.387068924559145)
# POINT (19.96698055043687 39.387068924559145)
# POINT (19.96858055043687 39.387068924559145)
# POINT (19.97018055043687 39.387068924559145)
# POINT (19.97178055043687 39.387068924559145)
# POINT (19.973380550436868 39.387068924559145)
# POINT (19.974980550436868 39.387068924559145)
# POINT (19.976580550436868 39.387068924559145)
# POINT (19.978180550436868 39.387068924559145)
# POINT (19.979780550436868 39.387068924559145)
# POINT (19.981380550436867 39.387068924559145)
# POINT (19.982980550436867 39.387068924559145)
# POINT (19.984580550436867 39.387068924559145)
# POINT (19.986180550436867 39.387068924559145)
# POINT (19.987780550436867 39.387068924559145)
# POINT (19.989380550436866 39.387068924559145)
# POINT (19.990980550436866 39.387068924559145)
# POINT (19.992580550436866 39.387068924559145)
# POINT (19.994180550436866 39.387068924559145)
# POINT (19.995780550436866 39.387068924559145)
# POINT (19.997380550436866 39.387068924559145)
# POINT (19.998980550436865 39.387068924559145)
# POINT (20.000580550436865 39.387068924559145)
# POINT (20.002180550436865 39.387068924559145)
# POINT (20.003780550436865 39.387068924559145)
# POINT (20.005380550436865 39.387068924559145)
# POINT (20.006980550436865 39.387068924559145)
# POINT (20.008580550436864 39.387068924559145)
# POINT (20.010180550436864 39.387068924559145)
# POINT (20.011780550436864 39.387068924559145)
# POINT (20.013380550436864 39.387068924559145)
# POINT (20.014980550436864 39.387068924559145)
# POINT (20.016580550436863 39.387068924559145)
# POINT (20.018180550436863 39.387068924559145)
# POINT (20.019780550436863 39.387068924559145)
# POINT (20.021380550436863 39.387068924559145)
# POINT (20.022980550436863 39.387068924559145)
# POINT (20.024580550436863 39.387068924559145)
# POINT (20.026180550436862 39.387068924559145)
# POINT (20.027780550436862 39.387068924559145)
# POINT (20.029380550436862 39.387068924559145)
# POINT (20.030980550436862 39.387068924559145)
# POINT (20.03258055043686 39.387068924559145)
# POINT (20.03418055043686 39.387068924559145)
# POINT (20.03578055043686 39.387068924559145)
# POINT (20.03738055043686 39.387068924559145)
# POINT (20.03898055043686 39.387068924559145)
# POINT (20.04058055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.04218055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.04378055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.04538055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.04698055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.04858055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.05018055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.05178055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.05338055043686 39.387068924559145)
# Loading page (1/2)
# Rendering (2/2)
# Done
# POINT (20.05498055043686 39.387068924559145)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 15
#      13 for x in np.arange(min_lat, max_lat, lat_interval):
#      14     for y in np.arange(min_lon, max_lon, lon_interval):
# ---> 15         create_map_tiles(x, y, border, width, height)
#
# Cell In[26], line 23, in create_map_tiles(long, lati, border, width, height)
#      21 m.save(f'../images/temp/{long}_{lati}_sat.html')
#      22 ## Convert to png file and save to permanent folder
# ---> 23 imgkit.from_file(f'../images/temp/{long}_{lati}_sat.html',f'../images/satelite_tiles/{long}_{lati}_sat.png')
#      24 ##Destroy html file
#      25 os.remove(f'../images/temp/{long}_{lati}_sat.html') #regex to read in lonlat from filepath
#
# File ~/anaconda3/lib/python3.10/site-packages/imgkit/api.py:72, in from_file(filename, output_path, options, toc, cover, css, config, cover_first)
#      49 """
#      50 Convert HTML file/files to IMG file/files
#      51
#    (...)
#      60 :return: True when success
#      61 """
#      62 rtn = IMGKit(
#      63     filename,
#      64     "file",
#    (...)
#      70     cover_first=cover_first,
#      71 )
# ---> 72 return rtn.to_img(output_path)
#
# File ~/anaconda3/lib/python3.10/site-packages/imgkit/imgkit.py:257, in IMGKit.to_img(self, path)
#     249     raise OSError(
#     250         "{}\n"
#     251         'You will need to run wkhtmltoimage within a "virtual" X server.\n'
#     252         "Go to the link below for more information\n"
#     253         "http://wkhtmltopdf.org".format(stderr)
#     254     )
#     256 if "Error" in stderr:
# --> 257     raise OSError("wkhtmltoimage reported an error:\n" + stderr)
#     259 if exit_code != 0:
#     260     xvfb_error = ""
#
# OSError: wkhtmltoimage reported an error:
# Loading page (1/2)
# Error: Failed to load https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://code.jquery.com/jquery-1.12.4.min.js, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145675&y=99821&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145676&y=99821&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145675&y=99822&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145676&y=99822&z=18, with network status code 99 and http status code 0 - Operation timed out
# Rendering (2/2)
# Done
# Exit with code 1 due to network error: UnknownNetworkError

# %%
# Resample using a shifted matrix by one half the window height and width.  
#This should eliminate instances where houses land on image boundaries.
border = coastline
lon_interval = 0.0016
width = 300
lat_interval = 0.0012
height = 300


#plot a boundary using the northernmost, easternmost, etc. points in your border geometry
min_lon, min_lat, max_lon, max_lat = coastline.total_bounds

for x in np.arange(min_lat + 0.5 * lat_interval,
                   max_lat - 0.5 * lat_interval,
                   lat_interval):
    for y in np.arange(min_lon + 0.5 * lon_interval,
                       max_lon - 0.5 * lon_interval,
                       lon_interval):
        create_map_tiles(x, y, border, width, height)
# Out:
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# ...
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# Loading page (1/2)
# Rendering (2/2)
# Done
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[38], line 19
#      13 for x in np.arange(min_lat + 0.5 * lat_interval,
#      14                    max_lat - 0.5 * lat_interval,
#      15                    lat_interval):
#      16     for y in np.arange(min_lon + 0.5 * lon_interval,
#      17                        max_lon - 0.5 * lon_interval,
#      18                        lon_interval):
# ---> 19         create_map_tiles(x, y, border, width, height)
#
# Cell In[37], line 22, in create_map_tiles(long, lati, border, width, height)
#      20 m.save(f'../images/temp/{long}_{lati}_sat.html')
#      21 ## Convert to png file and save to permanent folder
# ---> 22 imgkit.from_file(f'../images/temp/{long}_{lati}_sat.html',f'../images/satelite_tiles/{long}_{lati}_sat.png')
#      23 ##Destroy html file
#      24 os.remove(f'../images/temp/{long}_{lati}_sat.html') #regex to read in lonlat from filepath
#
# File ~/anaconda3/lib/python3.10/site-packages/imgkit/api.py:72, in from_file(filename, output_path, options, toc, cover, css, config, cover_first)
#      49 """
#      50 Convert HTML file/files to IMG file/files
#      51
#    (...)
#      60 :return: True when success
#      61 """
#      62 rtn = IMGKit(
#      63     filename,
#      64     "file",
#    (...)
#      70     cover_first=cover_first,
#      71 )
# ---> 72 return rtn.to_img(output_path)
#
# File ~/anaconda3/lib/python3.10/site-packages/imgkit/imgkit.py:257, in IMGKit.to_img(self, path)
#     249     raise OSError(
#     250         "{}\n"
#     251         'You will need to run wkhtmltoimage within a "virtual" X server.\n'
#     252         "Go to the link below for more information\n"
#     253         "http://wkhtmltopdf.org".format(stderr)
#     254     )
#     256 if "Error" in stderr:
# --> 257     raise OSError("wkhtmltoimage reported an error:\n" + stderr)
#     259 if exit_code != 0:
#     260     xvfb_error = ""
#
# OSError: wkhtmltoimage reported an error:
# Loading page (1/2)
# Error: Failed to load https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145707&y=99814&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145708&y=99814&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145707&y=99815&z=18, with network status code 99 and http status code 0 - Operation timed out
# Error: Failed to load https://mt1.google.com/vt/lyrs=s&x=145708&y=99815&z=18, with network status code 99 and http status code 0 - Operation timed out
# Rendering (2/2)
# Done
# Exit with code 1 due to network error: UnknownNetworkError

# %% [markdown]
# > Result: Images covering the full island with minimal inclusion of the sea, captured at half-frame intervals vertically and horizontally.

# %% [markdown]
# ![Beach](../images/satelite_tiles/39.37206892455918_20.07498055043686_sat.png)
# ![Beach Offset](../images/satelite_tiles/39.37266892455918_20.074180550436857_sat.png)
